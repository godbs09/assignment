# %%
-1. 사칙연산 코딩하기

# %%
#덧셈
3+4
# Out:
# 7

# %%
#뺄셈
10-5
# Out:
# 5

# %%
#곱셈
100*2
# Out:
# 200

# %%
#나눗셈
10/2
# Out:
# 5.0

# %%
#거듭제곱
10**3
# Out:
# 1000

# %%
#나눗셈에서 몫 값만
11//3
# Out:
# 3

# %%
#나머지 값
10%3
# Out:
# 1

# %%
2+3*8
# Out:
# 26

# %%
11+7/2
# Out:
# 14.5

# %%
12-(2*5+2)
# Out:
# 0

# %%
#부등호
2 > 3
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
2 == 2
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 >= 3
# Out:
# False

# %%
2 <= 2
# Out:
# True

# %%
-2. 변수명 설정하기

# %%
ABC = 5

# %%
ABC
# Out:
# 5

# %%
#변수로 사칙연산하기

# %%
a = 1
b = 5
c = 2

# %%
a + b + c
# Out:
# 8

# %%
a + b - c
# Out:
# 4

# %%
a * b / c
# Out:
# 2.5

# %%
x = "안산대학교"

# %%
x
# Out:
# '안산대학교'

# %%
s = "학생"

# %%
s
# Out:
# '학생'

# %%
x + s
# Out:
# '안산대학교학생'

# %%
-3. 라이브러리(Library)를 별칭으로 불러오기

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --------------------------- ------------ 8.7/12.8 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 43.5 MB/s  0:00:00
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------  10.7/11.0 MB 59.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 54.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
# ...

# %%
import numpy as np

# %%
import pandas as p

# %%
-4. 데이터(문자형 또는 정수형)를 리스트(list) 형식으로 코딩하기

# %%
crime = ["살인", "강도", "절도"]

# %%
crime
# Out:
# ['살인', '강도', '절도']

# %%
crime[0]
# Out:
# '살인'

# %%
crime[2]
# Out:
# '절도'

# %%
crime.append("사기")

# %%
crime
# Out:
# ['살인', '강도', '절도', '사기']

# %%
crime[3]
# Out:
# '사기'

# %%
del crime[2]

# %%
crime
# Out:
# ['살인', '강도', '사기']

# %%
num1 = ['one', 'two', 'three', 'four']
num2 = ['siz', 'seven', 'eight', 'nine']
num2.extend(num1)

# %%
print(num2)
# Out:
# ['siz', 'seven', 'eight', 'nine', 'one', 'two', 'three', 'four']

# %%
num1.extend(num2)

# %%
print(num1)
# Out:
# ['one', 'two', 'three', 'four', 'siz', 'seven', 'eight', 'nine', 'one', 'two', 'three', 'four']

# %%
num = ['one', 'two', 'three', 'four']
num.sort()
print(num)
# Out:
# ['four', 'one', 'three', 'two']

# %%
num = ['one', 'two', 'three', 'four']
newnum = sorted(num)
print(newnum)
print(num)
# Out:
# ['four', 'one', 'three', 'two']
# ['one', 'two', 'three', 'four']

# %%
num = [1,2,3,4]
num.sort(reverse=True)
print(num)
# Out:
# [4, 3, 2, 1]

# %%
len(num)
# Out:
# 4

# %%
result = sum(num)
print(result)
# Out:
# 10

# %%
-5. 리스트 데이터의 평균 (mean)값을 코딩하기

# %%
num = [100, 200, 300, 400, 500, 600, 700]
np.mean(num)
# Out:
# np.float64(400.0)

# %%
num1 = [100232, 231, 24445, 221, 123, 23, 1123]
np.mean(num1)
# Out:
# np.float64(18056.85714285714)

# %%
-6. 데이터(문자형) 튜플 (tuple) 형식으로 코딩하기

# %%
crime8 = ("살인", "강도", "절도", "학교")
crime8
# Out:
# ('살인', '강도', '절도', '학교')

# %%
type(crime8)
# Out:
# tuple

# %%
print(crime8[0])
# Out:
# 살인

# %%
print(crime8[1:])
# Out:
# ('강도', '절도', '학교')

# %%
-7. 데이터를 딕셔너리(dictionary) 형식으로 코딩하기

# %%
crime6 = { '살인':54100, '강도': 55000, '절도': 56200, '사기': 56900, '도박': 57000}

# %%
type(crime6)
# Out:
# dict

# %%
crime6
# Out:
# {'살인': 54100, '강도': 55000, '절도': 56200, '사기': 56900, '도박': 57000}

# %%
crime6["강도"]
# Out:
# 55000

# %%
len(crime6)
# Out:
# 5

# %%
score ={}

# %%
type(score)
# Out:
# dict

# %%
score["경찰청"] = 100

# %%
score
# Out:
# {'경찰청': 100}

# %%
del score["경찰청"]

# %%
score
# Out:
# {}

# %%
crime6['마약'] = 51000

# %%
crime6
# Out:
# {'살인': 54100, '강도': 55000, '절도': 56200, '사기': 56900, '도박': 57000, '마약': 51000}

# %%
crime6.keys()
# Out:
# dict_keys(['살인', '강도', '절도', '사기', '도박', '마약'])

# %%
crime6.values()
# Out:
# dict_values([54100, 55000, 56200, 56900, 57000, 51000])

# %%
-8. 조건문 작성하기

# %%
살인 = 20
if 살인 >= 10:
    print("코드제로")
# Out:
# 코드제로

# %%
살인 = 5
if 살인 <= 10:
    print("BLUE")
else:
    print("코드제로")
# Out:
# BLUE

# %%
살인 = 15
if 살인 <= 10:
    print("BLUE")
else:
    print("코드제로")
# Out:
# 코드제로

# %%
살인 = 5
if 살인 <= 10:
    print("BLUE")
elif 살인 >= 20:
    print("코드제로")
else:
    print("출동대기")
# Out:
# BLUE

# %%
살인 = 25
if 살인 <= 10:
    print("BLUE")
elif 살인 >= 20:
    print("코드제로")
else:
    print("출동대기")
# Out:
# 코드제로

# %%
살인 = 15
if 살인 <= 10:
    print("BLUE")
elif 살인 >= 20:
    print("코드제로")
else:
    print("출동대기")
# Out:
# 출동대기

# %%
살인 = 10
폭력 = 100
if 살인 <= 10 and 폭력 <= 200:
    print("BLUE")
elif 살인 >= 20 and 폭력 >= 400:
    print("코드제로")
else:
    print("출동대기")
# Out:
# BLUE

# %%
살인 = 30
폭력 = 300
if 살인 <= 10 or 폭력 <= 200:
    print("blue")
elif 살인 >= 20 or 폭력 >= 400:
    print("코드제로")
else: 
    print("출동대기")
# Out:
# 코드제로

# %%
-9. pandas 를 이용하여 DataFrame을 ‘df'로 생성하기

# %%
income_list = pd.Series([45652, 26392, 46405], index=["남성","남성","여성"])
income_list
# Out:
# 남성    45652
# 남성    26392
# 여성    46405
# dtype: int64

# %%
income_list.index.name = "성별","총소득"

# %%
income_list
# Out:
# (성별, 총소득)
# 남성    45652
# 남성    26392
# 여성    46405
# dtype: int64

# %%
df = pd.DataFrame(income_list)

# %%
df
# Out:
#                0
# (성별, 총소득)
# 남성         45652
# 남성         26392
# 여성         46405

# %%
from pandas import DataFrame

# %%
from datetime import datetime, timedelta
import random

# %%
crime = [{"살인":10, "강도":55, "절도":150},
         {"살인":5, "강도":65, "절도":200},
         {"살인":20, "강도":40, "절도":350}]

police = ["서울경찰청", "부산경찰청", "인천경찰청"]

df = DataFrame(data = crime, index = police)
print(df)
# Out:
#        살인  강도   절도
# 서울경찰청  10  55  150
# 부산경찰청   5  65  200
# 인천경찰청  20  40  350

# %%
df.describe()
# Out:
#               살인         강도          절도
# count   3.000000   3.000000    3.000000
# mean   11.666667  53.333333  233.333333
# std     7.637626  12.583057  104.083300
# min     5.000000  40.000000  150.000000
# 25%     7.500000  47.500000  175.000000
# 50%    10.000000  55.000000  200.000000
# 75%    15.000000  60.000000  275.000000
# max    20.000000  65.000000  350.000000
