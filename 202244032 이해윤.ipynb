# %%
2**50
# Out:
# 1125899906842624

# %%
30 >= 15
# Out:
# True

# %%
ansan_police = "경기경찰청 안산경찰서"

# %%
ansan_police
# Out:
# '경기경찰청 안산경찰서'

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
crime = ["살인", "강도", "절도","사기","도박"]

# %%
crime
# Out:
# ['살인', '강도', '절도', '사기', '도박']

# %%
type(crime)
# Out:
# list

# %%
crime_num = [54100,55000,56200,56900,57000]

# %%
crime_num
# Out:
# [54100, 55000, 56200, 56900, 57000]

# %%
type(crime_num)
# Out:
# list

# %%
# !pip install numpy

# %%
import numpy as np

# %%
np.mean(crime_num)
# Out:
# np.float64(55840.0)

# %%
crime3 = { '살인':100, '강도': 550, '절도': 1200, '사기': 800, '도박': 750}

# %%
crime3
# Out:
# {'살인': 100, '강도': 550, '절도': 1200, '사기': 800, '도박': 750}

# %%
type(crime3)
# Out:
# dict

# %%
살인 = 7
if 살인 <= 5:
    print("Blue")
elif 살인 >= 20:
    print("코드 제로")
else:
    print("대기")
# Out:
# 대기

# %%
살인 = 30
폭력 = 500
if 살인 <= 10 and 폭력 <= 200:
    print("blue")
elif 살인 >= 20 and 폭력 >= 400:
    print("코드제로")
else:
    print("대기")
# Out:
# 코드제로

# %%
from pandas import DataFrame

# %%
crime = [{"살인":10, "강도":55, "절도":50},
         {"살인":5, "강도":65, "절도":70},
         {"살인":20, "강도":40, "절도":35}]

police = ["서울경찰청", "부산경찰청", "인천경찰청"]

df = DataFrame(data = crime, index = police)
print(df)
# Out:
#        살인  강도  절도
# 서울경찰청  10  55  50
# 부산경찰청   5  65  70
# 인천경찰청  20  40  35

# %%
df.describe()
# Out:
#               살인         강도         절도
# count   3.000000   3.000000   3.000000
# mean   11.666667  53.333333  51.666667
# std     7.637626  12.583057  17.559423
# min     5.000000  40.000000  35.000000
# 25%     7.500000  47.500000  42.500000
# 50%    10.000000  55.000000  50.000000
# 75%    15.000000  60.000000  60.000000
# max    20.000000  65.000000  70.000000
